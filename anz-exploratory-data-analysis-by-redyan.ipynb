# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
step_1.check()
# Out:
# Correct:

# %%
my_filepath = "../input/anz-synthesised-transaction-dataset/anz.csv"
step_2.check()
# Out:
# Correct:

# %%
my_data = pd.read_csv(my_filepath)
step_3.check()
# Out:
# Correct:

# %%
# Print the first five rows of the data
my_data.head()
# Out:
#        status  card_present_flag bpay_biller_code         account currency  \
# 0  authorized                1.0              NaN  ACC-1598451071      AUD
# 1  authorized                0.0              NaN  ACC-1598451071      AUD
# 2  authorized                1.0              NaN  ACC-1222300524      AUD
# 3  authorized                1.0              NaN  ACC-1037050564      AUD
# 4  authorized                1.0              NaN  ACC-1598451071      AUD
#
#         long_lat txn_description                           merchant_id  \
# 0  153.41 -27.95             POS  81c48296-73be-44a7-befa-d053f48ce7cd
# 1  153.41 -27.95       SALES-POS  830a451c-316e-4a6a-bf25-e37caedca49e
# 2  151.23 -33.94             POS  835c231d-8cdf-4e96-859d-e9d571760cf0
# 3  153.10 -27.66       SALES-POS  48514682-c78a-4a88-b0da-2d6302e64673
# 4  153.41 -27.95       SALES-POS  b4e02c10-0852-4273-b8fd-7b3395e32eb0
#
#    merchant_code first_name  ...  age merchant_suburb merchant_state  \
# ...

# %%
my_data.tail()
# Out:
#            status  card_present_flag bpay_biller_code         account  \
# 12038  authorized                0.0              NaN  ACC-3021093232
# 12039  authorized                1.0              NaN  ACC-1608363396
# 12040  authorized                1.0              NaN  ACC-3827517394
# 12041  authorized                1.0              NaN  ACC-2920611728
# 12042  authorized                1.0              NaN  ACC-1443681913
#
#       currency       long_lat txn_description  \
# 12038      AUD  149.83 -29.47             POS
# 12039      AUD  151.22 -33.87       SALES-POS
# 12040      AUD  151.12 -33.89             POS
# 12041      AUD  144.96 -37.76       SALES-POS
# 12042      AUD  150.92 -33.77       SALES-POS
#
#                                 merchant_id  merchant_code first_name  ...  \
# 12038  32aa73dc-b7c2-4161-b14d-6271b96ce792            NaN    Melissa  ...
# 12039  296a0500-8552-48ac-ac81-ec37065b568e            NaN     Robert  ...
# ...

# %%
my_data = pd.read_csv(my_filepath)
step_3.check()
# Out:
# Correct:

# %%
sns.lineplot(data = my_data)
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs)>

# %%
sns.scatterplot(x=my_data['age'], y=my_data['amount'], hue=my_data['status'])
plt.figure(figsize=(28,28))

# %%
sns.scatterplot(x=my_data['age'], y=my_data['txn_description'], hue=my_data['status'])
plt.figure(figsize=(20,28))

# %%
sns.scatterplot(x=my_data['age'], y=my_data['movement'], hue=my_data['status'])
plt.figure(figsize=(20,28))

# %%
sns.scatterplot(x=my_data['age'], y=my_data['merchant_state'], hue=my_data['status'])
plt.figure(figsize=(20,28))

# %%
sns.lmplot(x='age', y='amount', hue='status', data= my_data)
plt.figure(figsize=(20,28))

# %%
sns.lmplot(x='age', y='amount', hue='merchant_state', data= my_data)
plt.figure(figsize=(20,28))

# %%
sns.lmplot(x='age', y='amount', hue='txn_description', data= my_data)
plt.figure(figsize=(20,28))

# %%
sns.lmplot(x='age', y='amount', hue='movement', data= my_data)
plt.figure(figsize=(20,28))

# %%
sns.regplot(x=my_data['age'], y=my_data['amount'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='amount'>

# %%
sns.barplot(x=my_data['age'], y=my_data['amount'])

plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')
